# %%
import pandas as pd 
import math

# %%
from google.colab import files
file = files.upload()  #upload file into google colab session
# Out:
#      <input type="file" id="files-0adb8bd6-8909-4199-ae09-24a71fb7fee2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0adb8bd6-8909-4199-ae09-24a71fb7fee2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("layoffs_data.csv")
df
# Out:
#             Company        Location        Industry  Laid_Off_Count  \
# 0            Swiggy       Bengaluru            Food           600.0
# 1           WeWork    New York City     Real Estate           300.0
# 2            Hubilo     SF Bay Area           Other           115.0
# 3        Riot Games     Los Angeles        Consumer            46.0
# 4            Fandom     SF Bay Area           Media             NaN
# ...             ...             ...             ...             ...
# 2017        Service     Los Angeles          Travel             NaN
# 2018   HopSkipDrive     Los Angeles  Transportation             8.0
# 2019    Panda Squad     SF Bay Area        Consumer             6.0
# 2020  Tamara Mellon     Los Angeles          Retail            20.0
# 2021       EasyPost  Salt Lake City       Logistics            75.0
#
#       Percentage                 Date  \
# 0           0.10  2023-01-19 00:00:00
# 1            NaN  2023-01-19 00:00:00
# ...

# %%
len(df.columns)
# Out:
# 12

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Company                         0
# Location                        0
# Industry                        0
# Laid_Off_Count                623
# Percentage                    657
# Date                            0
# Source                          0
# Funds_Raised                  153
# Stage                           0
# Date_Added                      0
# Country                         0
# List_of_Employees_Laid_Off      0
# dtype: int64

# %%
df.dtypes
# Out:
# Company                        object
# Location                       object
# Industry                       object
# Laid_Off_Count                float64
# Percentage                    float64
# Date                           object
# Source                         object
# Funds_Raised                  float64
# Stage                          object
# Date_Added                     object
# Country                        object
# List_of_Employees_Laid_Off     object
# dtype: object

# %%
#Dropping all the records that have mutual missing values in the columns Laidoff count, Percentage and Funds_Raised
count=[]
for i in range(len(df)):
  if(math.isnan(df["Laid_Off_Count"][i])==True and math.isnan(df["Percentage"][i])==True and math.isnan(df["Funds_Raised"][i])==True):
      df=df.drop(i)

# %%
df=df.reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# Company                         0
# Location                        0
# Industry                        0
# Laid_Off_Count                587
# Percentage                    621
# Date                            0
# Source                          0
# Funds_Raised                  117
# Stage                           0
# Date_Added                      0
# Country                         0
# List_of_Employees_Laid_Off      0
# dtype: int64

# %%
count=[]
for i in range(len(df)):
  if(math.isnan(df["Laid_Off_Count"][i])==True and math.isnan(df["Percentage"][i])==True):
    df=df.drop(i)

# %%
df=df.reset_index(drop=True)

# %%
#Replacing the remaining null values with 0
df=df.fillna(0)

# %%
df.isna().sum()
# Out:
# Company                       0
# Location                      0
# Industry                      0
# Laid_Off_Count                0
# Percentage                    0
# Date                          0
# Source                        0
# Funds_Raised                  0
# Stage                         0
# Date_Added                    0
# Country                       0
# List_of_Employees_Laid_Off    0
# dtype: int64

# %%
# !pip install astropy>=3.1
# !pip install sunpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 71.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 20.0 MB/s eta 0:00:00
# ...

# %%
#Cleaned or dropped more columns such as source and date_added
#below is the desreptive stats and also some graphs

# %%
df.head(10)
# Out:
#           Company       Location     Industry  Laid_Off_Count  Percentage  \
# 0          Swiggy      Bengaluru         Food           600.0        0.10
# 1         WeWork   New York City  Real Estate           300.0        0.00
# 2          Hubilo    SF Bay Area        Other           115.0        0.35
# 3      Riot Games    Los Angeles     Consumer            46.0        0.00
# 4         Magnite    Los Angeles    Marketing             0.0        0.06
# 5      Personalis    SF Bay Area   Healthcare             0.0        0.30
# 6         Wallbox      Barcelona       Energy             0.0        0.15
# 7       Microsoft        Seattle        Other         10000.0        0.05
# 8          Sophos         Oxford     Security           450.0        0.10
# 9  Teladoc Health  New York City   Healthcare           300.0        0.06
#
#                   Date                                             Source  \
# 0  2023-01-19 00:00:00  https://timesofindia.indiatimes.com/business/i...
# ...

# %%
#Dropping the columns that are totally unnecessary
New_Data= df.drop(['Source', 'Date_Added', 'List_of_Employees_Laid_Off'],axis=1)

# %%
New_Data
# Out:
#             Company        Location        Industry  Laid_Off_Count  \
# 0            Swiggy       Bengaluru            Food           600.0
# 1           WeWork    New York City     Real Estate           300.0
# 2            Hubilo     SF Bay Area           Other           115.0
# 3        Riot Games     Los Angeles        Consumer            46.0
# 4           Magnite     Los Angeles       Marketing             0.0
# ...             ...             ...             ...             ...
# 1709        Service     Los Angeles          Travel             0.0
# 1710   HopSkipDrive     Los Angeles  Transportation             8.0
# 1711    Panda Squad     SF Bay Area        Consumer             6.0
# 1712  Tamara Mellon     Los Angeles          Retail            20.0
# 1713       EasyPost  Salt Lake City       Logistics            75.0
#
#       Percentage                 Date  Funds_Raised     Stage        Country
# ...

# %%
New_Data.to_csv('Layoff-Data-Cleaned.csv')

# %%
New_Data['Funds_Raised'].median()
# Out:
# 131.5

# %%
from pandas.plotting import scatter_matrix
# %matplotlib inline               
import numpy as np
import matplotlib.pyplot as plt

# %%
scatter_matrix(New_Data.loc[:,'Laid_Off_Count':'Funds_Raised'],figsize=[10,10])
# Out:
# array([[<Axes: xlabel='Laid_Off_Count', ylabel='Laid_Off_Count'>,
#         <Axes: xlabel='Percentage', ylabel='Laid_Off_Count'>,
#         <Axes: xlabel='Funds_Raised', ylabel='Laid_Off_Count'>],
#        [<Axes: xlabel='Laid_Off_Count', ylabel='Percentage'>,
#         <Axes: xlabel='Percentage', ylabel='Percentage'>,
#         <Axes: xlabel='Funds_Raised', ylabel='Percentage'>],
#        [<Axes: xlabel='Laid_Off_Count', ylabel='Funds_Raised'>,
#         <Axes: xlabel='Percentage', ylabel='Funds_Raised'>,
#         <Axes: xlabel='Funds_Raised', ylabel='Funds_Raised'>]],
#       dtype=object)

# %%
New_Data.corr()
# Out:
# <ipython-input-23-7170a4c7a23d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   New_Data.corr()
#                 Laid_Off_Count  Percentage  Funds_Raised
# Laid_Off_Count        1.000000   -0.055169      0.112663
# Percentage           -0.055169    1.000000     -0.066369
# Funds_Raised          0.112663   -0.066369      1.000000

# %%
New_Data.head(5)
# Out:
#       Company    Location_HQ Industry  Laid_Off_Count  Percentage  \
# 0     Polygon      Bengaluru   Crypto           100.0        0.20
# 1      MyGate      Bengaluru    Other           200.0        0.30
# 2  Fireblocks  New York City   Crypto            30.0        0.05
# 3       Kinde         Sydney    Other             8.0        0.28
# 4      Fipola        Chennai     Food             NaN        1.00
#
#                   Date  Funds_Raised     Stage        Country
# 0  2023-02-21 00:00:00         451.0   Unknown          India
# 1  2023-02-20 00:00:00          79.0  Series B          India
# 2  2023-02-20 00:00:00        1000.0  Series E  United States
# 3  2023-02-20 00:00:00          10.0      Seed      Australia
# 4  2023-02-20 00:00:00           9.0  Series A  United States

# %%
platforms=New_Data['Laid_Off_Count']
platforms.value_counts(sort=True).plot.hist(orientation='vertical')
plt.show()

# %%
#area plot
sub_frame=New_Data[['Laid_Off_Count','Percentage','Funds_Raised']]

# %%
sub_frame
# Out:
#       Laid_Off_Count  Percentage  Funds_Raised
# 0              100.0        0.20         451.0
# 1              200.0        0.30          79.0
# 2               30.0        0.05        1000.0
# 3                8.0        0.28          10.0
# 4                NaN        1.00           9.0
# ...              ...         ...           ...
# 1528             NaN        1.00           5.1
# 1529             8.0        0.10          45.0
# 1530             6.0        0.75           1.0
# 1531            20.0        0.40          90.0
# 1532           500.0        0.14           NaN
#
# [1533 rows x 3 columns]
